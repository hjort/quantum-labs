# %% [markdown]
# https://youtu.be/mMwovHK2NrE?si=3FH7VujFjtOuA1ND

# %%
import qiskit

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
circuit = qiskit.QuantumCircuit(3, 3)

# %%
#circuit.initialize([1j, 0], 0)
#circuit.initialize([1, 0], 0)
#circuit.initialize([0, 1], 0)
#circuit.initialize([-1/np.sqrt(2)+1j/np.sqrt(2), 0], 0)
#circuit.initialize([1/np.sqrt(2), -1/np.sqrt(2)], 0)

#circuit.initialize([0, 1], 1)
#circuit.initialize([0, 1], 2)

# %%
circuit.draw('mpl')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
circuit.x(0)
circuit.barrier()

# %%
circuit.draw('mpl')

# %%
circuit.h(1)
circuit.cx(1, 2)

# %%
circuit.draw('mpl')

# %%
circuit.cx(0, 1)
circuit.h(0)

# %%
circuit.draw('mpl')

# %%
circuit.barrier()
circuit.measure([0,1], [0,1])

# %%
circuit.draw('mpl')

# %%
circuit.barrier()
circuit.cx(1, 2)
circuit.cz(0, 2)

# %%
circuit.draw('mpl')

# %%
circuit.measure(2, 2)

# %%
circuit.draw('mpl')

# %% [markdown]
# https://algassert.com/quirk#circuit=%7B%22cols%22%3A%5B%5B%22X%22%5D%2C%5B1%2C%22H%22%5D%2C%5B1%2C%22%E2%80%A2%22%2C%22X%22%5D%2C%5B%22%E2%80%A2%22%2C%22X%22%5D%2C%5B%22H%22%5D%2C%5B1%2C%22%E2%80%A2%22%2C%22X%22%5D%5D%7D

# %%
#simulator = qiskit.Aer.get_backend('qasm_simulator')
simulator = qiskit.Aer.get_backend('statevector_simulator')
simulator
# Out:
# StatevectorSimulator('statevector_simulator')

# %%
job = qiskit.execute(circuit, backend=simulator, shots=1024)
job

# %%
result = job.result()
result
# Out:
# Result(backend_name='statevector_simulator', backend_version='0.13.0', qobj_id='', job_id='63d33252-ef0e-4838-b8af-cb1e9057a8ea', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x4': 257, '0x5': 262, '0x6': 257, '0x7': 248}, statevector=Statevector([0.+0.0000000e+00j, 0.+0.0000000e+00j, 0.+0.0000000e+00j,
#              0.+0.0000000e+00j, 0.+0.0000000e+00j, 1.+1.2246468e-16j,
#              0.+0.0000000e+00j, 0.+0.0000000e+00j],
#             dims=(2, 2, 2))), header=QobjExperimentHeader(creg_sizes=[['c', 3]], global_phase=3.141592653589793, memory_slots=3, n_qubits=3, name='circuit-152', qreg_sizes=[['q', 3]], metadata={}), status=DONE, seed_simulator=2228768377, metadata={'time_taken': 0.05653112, 'num_bind_params': 1, 'parallel_state_update': 1, 'required_memory_mb': 1, 'input_qubit_map': [[2, 2], [1, 1], [0, 0]], 'method': 'statevector', 'device': 'CPU', 'num_qubits': 3, 'active_input_qubits': [0, 1, 2], 'num_clbits': 3, 'remapped_qubits': False, 'parallel_shots': 1, 'runtime_parameter_bind': False, 'max_memory_mb': 3868, 'noise': 'ideal', 'measure_sampling': False, 'batched_shots_optimization': False, 'result_types': {'statevector': 'save_statevector'}, 'result_subtypes': {'statevector': 'single'}, 'fusion': {'applied': False, 'max_fused_qubits': 5, 'threshold': 14, 'enabled': True}}, time_taken=0.05653112)], date=2023-11-15T23:38:41.456766, status=COMPLETED, header=None, metadata={'time_taken_parameter_binding': 2.5214e-05, 'time_taken_execute': 0.056680727, 'omp_enabled': True, 'max_gpu_memory_mb': 0, 'max_memory_mb': 3868, 'parallel_experiments': 1}, time_taken=0.07179880142211914)

# %%
counts = result.get_counts()
counts
# Out:
# {'100': 257, '101': 262, '110': 257, '111': 248}

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(counts)

# %%
sv = result.get_statevector()
sv
# Out:
# Statevector([0.+0.0000000e+00j, 0.+0.0000000e+00j, 0.+0.0000000e+00j,
#              0.+0.0000000e+00j, 0.+0.0000000e+00j, 1.+1.2246468e-16j,
#              0.+0.0000000e+00j, 0.+0.0000000e+00j],
#             dims=(2, 2, 2))

# %%
from qiskit.tools.visualization import plot_bloch_multivector

# %%
plot_bloch_multivector(sv)
